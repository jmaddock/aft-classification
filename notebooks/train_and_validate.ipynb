# %%
import json
import time
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from autosklearn.metrics import balanced_accuracy, precision, recall, f1
import autosklearn.classification

from smac.tae import StatusType

# %%
def generate_sample(df,n):
    pos = df.loc[df['aft_net_sign_helpful'] > 0].sample(n)
    neg = df.loc[df['aft_net_sign_helpful'] < 0].sample(n)
    sample = pos.append(neg)
    return sample

# %%
def results_to_table(cls):
    results = pd.DataFrame.from_dict(cls.cv_results_)
    params = results['params'].apply(pd.Series)
    results = pd.concat([results.drop(['params'],axis=1),params],axis=1)
    return results

# %%
def k_fold_train(features,lables):
    skf = StratifiedKFold(n_splits=k,shuffle=True)
    cls = autosklearn.classification.AutoSklearnClassifier(
        time_left_for_this_task=120,
        per_run_time_limit=30,
        ensemble_size=0,
        scoring_functions=[balanced_accuracy, precision, recall, f1],
        resampling_strategy = StratifiedKFold,
        n_jobs = threads
    )
    cls.fit(features, labels)
    return cls

# %%
infile_path = '../datasets/vectorized/aft_vectorized_01-29-21.json'
sample_size = 10
k = 5
threads = 4

def main(cls=None):
    with open(infile_path,'r') as filestream:
        full_df = pd.DataFrame(json.load(filestream))
    sample_df = generate_sample(full_df,sample_size)
        
    features = pd.DataFrame(sample_df['feature_vector'].values.tolist()).to_numpy()
    labels = sample_df['aft_net_sign_helpful'].to_numpy()

    features_train, features_test, labels_train, labels_test = train_test_split(features, labels, random_state=1)

    if not cls:
        cls = k_fold_train(features, labels)
        
    #print(results_to_table(cls))
    
    print(['Numerical'] * np.shape(features)[1])

    
main(cls)
# Out:
# ['Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical', 'Numerical']

# %%
results = pd.DataFrame.from_dict(cls.cv_results_)
params = pd.concat([results[['rank_test_scores','mean_test_score']],results['params'].apply(pd.Series)],axis=1).sort_values('rank_test_scores')
params
# Out:
#     rank_test_scores  mean_test_score balancing:strategy  \
# 10                 1             0.74               none
# 13                 2             0.62          weighting
# 8                  2             0.62               none
# 23                 4             0.60          weighting
# 14                 4             0.60               none
# 12                 4             0.60               none
# 6                  7             0.60          weighting
# 22                 8             0.58          weighting
# 5                  8             0.58          weighting
# 15                 8             0.58          weighting
# 24                11             0.56               none
# 20                12             0.56               none
# 0                 12             0.56               none
# 4                 12             0.56          weighting
# 16                15             0.54          weighting
# 2                 15             0.54               none
# 1                 17             0.54          weighting
# 19                18             0.52               none
# 7                 19             0.50          weighting
# 11                19             0.50          weighting
# 25                21             0.48               none
# 17                21             0.48               none
# 9                 23             0.00          weighting
# 18                23             0.00               none
# 21                23             0.00               none
# 3                 23             0.00          weighting
# 26                23             0.00               none
#
#    classifier:__choice__  \
# 10         random_forest
# 13                   mlp
# 8    k_nearest_neighbors
# 23    passive_aggressive
# 14            libsvm_svc
# 12     gradient_boosting
# 6          random_forest
# 22                   mlp
# 5          random_forest
# 15         decision_tree
# 24                   mlp
# 20              adaboost
# 0          random_forest
# 4          random_forest
# 16         random_forest
# 2      gradient_boosting
# 1            extra_trees
# 19              adaboost
# 7      gradient_boosting
# 11     gradient_boosting
# 25         random_forest
# 17     gradient_boosting
# 9                    mlp
# 18     gradient_boosting
# 21         random_forest
# 3    k_nearest_neighbors
# 26         random_forest
#
#    data_preprocessing:categorical_transformer:categorical_encoding:__choice__  \
# 10                                        no_encoding
# 13                                   one_hot_encoding
# 8                                         no_encoding
# 23                                        no_encoding
# 14                                        no_encoding
# 12                                        no_encoding
# 6                                         no_encoding
# 22                                   one_hot_encoding
# 5                                         no_encoding
# 15                                   one_hot_encoding
# 24                                        no_encoding
# 20                                   one_hot_encoding
# 0                                    one_hot_encoding
# 4                                         no_encoding
# 16                                   one_hot_encoding
# 2                                    one_hot_encoding
# 1                                         no_encoding
# 19                                   one_hot_encoding
# 7                                         no_encoding
# 11                                        no_encoding
# 25                                        no_encoding
# 17                                        no_encoding
# 9                                         no_encoding
# 18                                   one_hot_encoding
# 21                                        no_encoding
# 3                                    one_hot_encoding
# 26                                        no_encoding
#
#    data_preprocessing:categorical_transformer:category_coalescence:__choice__  \
# 10                                     no_coalescense
# 13                                     no_coalescense
# 8                                  minority_coalescer
# 23                                 minority_coalescer
# 14                                     no_coalescense
# 12                                     no_coalescense
# 6                                  minority_coalescer
# 22                                     no_coalescense
# 5                                  minority_coalescer
# 15                                     no_coalescense
# 24                                     no_coalescense
# 20                                 minority_coalescer
# 0                                  minority_coalescer
# 4                                      no_coalescense
# 16                                 minority_coalescer
# 2                                  minority_coalescer
# 1                                  minority_coalescer
# 19                                 minority_coalescer
# 7                                      no_coalescense
# 11                                 minority_coalescer
# 25                                     no_coalescense
# 17                                 minority_coalescer
# 9                                      no_coalescense
# 18                                 minority_coalescer
# 21                                     no_coalescense
# 3                                      no_coalescense
# 26                                     no_coalescense
#
#    data_preprocessing:numerical_transformer:imputation:strategy  \
# 10                                             median
# 13                                      most_frequent
# 8                                       most_frequent
# 23                                      most_frequent
# 14                                             median
# 12                                             median
# 6                                       most_frequent
# 22                                      most_frequent
# 5                                                mean
# 15                                               mean
# 24                                             median
# 20                                               mean
# 0                                                mean
# 4                                       most_frequent
# 16                                             median
# 2                                              median
# 1                                              median
# 19                                               mean
# 7                                       most_frequent
# 11                                      most_frequent
# 25                                             median
# 17                                      most_frequent
# 9                                              median
# 18                                             median
# 21                                               mean
# 3                                                mean
# 26                                             median
#
#    data_preprocessing:numerical_transformer:rescaling:__choice__  \
# 10                               quantile_transformer
# 13                                        standardize
# 8                                         standardize
# 23                                      robust_scaler
# 14                                        standardize
# 12                                             minmax
# 6                                       robust_scaler
# 22                                        standardize
# 5                                quantile_transformer
# 15                                          normalize
# 24                                        standardize
# 20                                          normalize
# 0                                         standardize
# 4                                         standardize
# 16                                             minmax
# 2                                         standardize
# 1                                           normalize
# 19                                      robust_scaler
# 7                                quantile_transformer
# 11                                      robust_scaler
# 25                                      robust_scaler
# 17                                      robust_scaler
# 9                                              minmax
# 18                                      robust_scaler
# 21                                               none
# 3                                           normalize
# 26                               quantile_transformer
#
#            feature_preprocessor:__choice__ classifier:random_forest:bootstrap  \
# 10                  random_trees_embedding                               True
# 13                   feature_agglomeration                                NaN
# 8   extra_trees_preproc_for_classification                                NaN
# 23                           kitchen_sinks                                NaN
# 14                   feature_agglomeration                                NaN
# 12              liblinear_svc_preprocessor                                NaN
# 6   extra_trees_preproc_for_classification                               True
# 22  extra_trees_preproc_for_classification                                NaN
# 5   extra_trees_preproc_for_classification                              False
# 15                        no_preprocessing                                NaN
# 24                   feature_agglomeration                                NaN
# 20                              polynomial                                NaN
# 0                         no_preprocessing                               True
# 4   extra_trees_preproc_for_classification                               True
# 16  extra_trees_preproc_for_classification                               True
# 2   extra_trees_preproc_for_classification                                NaN
# 1   extra_trees_preproc_for_classification                                NaN
# 19  extra_trees_preproc_for_classification                                NaN
# 7                    feature_agglomeration                                NaN
# 11                   feature_agglomeration                                NaN
# 25                  random_trees_embedding                               True
# 17                        no_preprocessing                                NaN
# 9                                 fast_ica                                NaN
# 18                              polynomial                                NaN
# 21                              polynomial                              False
# 3                                 fast_ica                                NaN
# 26                  random_trees_embedding                              False
#
#     ... classifier:adaboost:max_depth classifier:adaboost:n_estimators  \
# 10  ...                           NaN                              NaN
# 13  ...                           NaN                              NaN
# 8   ...                           NaN                              NaN
# 23  ...                           NaN                              NaN
# 14  ...                           NaN                              NaN
# 12  ...                           NaN                              NaN
# 6   ...                           NaN                              NaN
# 22  ...                           NaN                              NaN
# 5   ...                           NaN                              NaN
# 15  ...                           NaN                              NaN
# 24  ...                           NaN                              NaN
# 20  ...                           2.0                             56.0
# 0   ...                           NaN                              NaN
# 4   ...                           NaN                              NaN
# 16  ...                           NaN                              NaN
# 2   ...                           NaN                              NaN
# 1   ...                           NaN                              NaN
# 19  ...                           3.0                            406.0
# 7   ...                           NaN                              NaN
# 11  ...                           NaN                              NaN
# 25  ...                           NaN                              NaN
# 17  ...                           NaN                              NaN
# 9   ...                           NaN                              NaN
# 18  ...                           NaN                              NaN
# 21  ...                           NaN                              NaN
# 3   ...                           NaN                              NaN
# 26  ...                           NaN                              NaN
#
#     classifier:mlp:validation_fraction classifier:passive_aggressive:C  \
# 10                                 NaN                             NaN
# 13                                 NaN                             NaN
# 8                                  NaN                             NaN
# 23                                 NaN                        0.148332
# 14                                 NaN                             NaN
# 12                                 NaN                             NaN
# 6                                  NaN                             NaN
# 22                                 0.1                             NaN
# 5                                  NaN                             NaN
# 15                                 NaN                             NaN
# 24                                 0.1                             NaN
# 20                                 NaN                             NaN
# 0                                  NaN                             NaN
# 4                                  NaN                             NaN
# 16                                 NaN                             NaN
# 2                                  NaN                             NaN
# 1                                  NaN                             NaN
# 19                                 NaN                             NaN
# 7                                  NaN                             NaN
# 11                                 NaN                             NaN
# 25                                 NaN                             NaN
# 17                                 NaN                             NaN
# 9                                  NaN                             NaN
# 18                                 NaN                             NaN
# 21                                 NaN                             NaN
# 3                                  NaN                             NaN
# 26                                 NaN                             NaN
#
#     classifier:passive_aggressive:average  \
# 10                                    NaN
# 13                                    NaN
# 8                                     NaN
# 23                                   True
# 14                                    NaN
# 12                                    NaN
# 6                                     NaN
# 22                                    NaN
# 5                                     NaN
# 15                                    NaN
# 24                                    NaN
# 20                                    NaN
# 0                                     NaN
# 4                                     NaN
# 16                                    NaN
# 2                                     NaN
# 1                                     NaN
# 19                                    NaN
# 7                                     NaN
# 11                                    NaN
# 25                                    NaN
# 17                                    NaN
# 9                                     NaN
# 18                                    NaN
# 21                                    NaN
# 3                                     NaN
# 26                                    NaN
#
#     classifier:passive_aggressive:fit_intercept  \
# 10                                          NaN
# 13                                          NaN
# 8                                           NaN
# 23                                         True
# 14                                          NaN
# 12                                          NaN
# 6                                           NaN
# 22                                          NaN
# 5                                           NaN
# 15                                          NaN
# 24                                          NaN
# 20                                          NaN
# 0                                           NaN
# 4                                           NaN
# 16                                          NaN
# 2                                           NaN
# 1                                           NaN
# 19                                          NaN
# 7                                           NaN
# 11                                          NaN
# 25                                          NaN
# 17                                          NaN
# 9                                           NaN
# 18                                          NaN
# 21                                          NaN
# 3                                           NaN
# 26                                          NaN
#
#     classifier:passive_aggressive:loss  classifier:passive_aggressive:tol  \
# 10                                 NaN                                NaN
# 13                                 NaN                                NaN
# 8                                  NaN                                NaN
# 23                       squared_hinge                           0.000165
# 14                                 NaN                                NaN
# 12                                 NaN                                NaN
# 6                                  NaN                                NaN
# 22                                 NaN                                NaN
# 5                                  NaN                                NaN
# 15                                 NaN                                NaN
# 24                                 NaN                                NaN
# 20                                 NaN                                NaN
# 0                                  NaN                                NaN
# 4                                  NaN                                NaN
# 16                                 NaN                                NaN
# 2                                  NaN                                NaN
# 1                                  NaN                                NaN
# 19                                 NaN                                NaN
# 7                                  NaN                                NaN
# 11                                 NaN                                NaN
# 25                                 NaN                                NaN
# 17                                 NaN                                NaN
# 9                                  NaN                                NaN
# 18                                 NaN                                NaN
# 21                                 NaN                                NaN
# 3                                  NaN                                NaN
# 26                                 NaN                                NaN
#
#     feature_preprocessor:kitchen_sinks:gamma  \
# 10                                       NaN
# 13                                       NaN
# 8                                        NaN
# 23                                  0.000136
# 14                                       NaN
# 12                                       NaN
# 6                                        NaN
# 22                                       NaN
# 5                                        NaN
# 15                                       NaN
# 24                                       NaN
# 20                                       NaN
# 0                                        NaN
# 4                                        NaN
# 16                                       NaN
# 2                                        NaN
# 1                                        NaN
# 19                                       NaN
# 7                                        NaN
# 11                                       NaN
# 25                                       NaN
# 17                                       NaN
# 9                                        NaN
# 18                                       NaN
# 21                                       NaN
# 3                                        NaN
# 26                                       NaN
#
#    feature_preprocessor:kitchen_sinks:n_components
# 10                                             NaN
# 13                                             NaN
# 8                                              NaN
# 23                                           148.0
# 14                                             NaN
# 12                                             NaN
# 6                                              NaN
# 22                                             NaN
# 5                                              NaN
# 15                                             NaN
# 24                                             NaN
# 20                                             NaN
# 0                                              NaN
# 4                                              NaN
# 16                                             NaN
# 2                                              NaN
# 1                                              NaN
# 19                                             NaN
# 7                                              NaN
# 11                                             NaN
# 25                                             NaN
# 17                                             NaN
# 9                                              NaN
# 18                                             NaN
# 21                                             NaN
# 3                                              NaN
# 26                                             NaN
#
# [27 rows x 122 columns]

# %%
def get_runhistory_models_performance(automl):
    metric = cls.automl_._metric
    data = automl.automl_.runhistory_.data
    performance_list = []
    for run_key, run_value in data.items():
        if run_value.status != StatusType.SUCCESS:
            # Ignore crashed runs
            continue
        # Alternatively, it is possible to also obtain the start time with ``run_value.starttime``
        endtime = pd.Timestamp(time.strftime('%Y-%m-%d %H:%M:%S',
                                             time.localtime(run_value.endtime)))
        print(run_value.additional_info)
        val_score = metric._optimum - (metric._sign * run_value.cost)
        test_score = metric._optimum - (metric._sign * run_value.additional_info['test_loss'])
        train_score = metric._optimum - (metric._sign * run_value.additional_info['train_loss'])
        performance_list.append({
            'Timestamp': endtime,
            'single_best_optimization_score': val_score,
            'single_best_test_score': test_score,
            'single_best_train_score': train_score,
        })
    return pd.DataFrame(performance_list)

get_runhistory_models_performance(cls)
# Out:
# {'accuracy': 0.44000000000000006, 'balanced_accuracy': 0.43527777777777776, 'precision': 0.4163174603174603, 'recall': 0.5166666666666667, 'f1': 0.480952380952381, 'duration': 8.533705949783325, 'num_run': 2, 'train_loss': 0.039999999999999994, 'configuration_origin': 'Initial design'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-d986fc27fc5c> in <module>
#      22     return pd.DataFrame(performance_list)
#      23
# ---> 24 get_runhistory_models_performance(cls)
#
# <ipython-input-44-d986fc27fc5c> in get_runhistory_models_performance(automl)
#      12         print(run_value.additional_info)
#      13         val_score = metric._optimum - (metric._sign * run_value.cost)
# ---> 14         test_score = metric._optimum - (metric._sign * run_value.additional_info['test_loss'])
#      15         train_score = metric._optimum - (metric._sign * run_value.additional_info['train_loss'])
#      16         performance_list.append({
#
# KeyError: 'test_loss'

# %%
resutls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9215a59ccc43> in <module>
# ----> 1 resutls
#
# NameError: name 'resutls' is not defined

# %%
pd.DataFrame.from_dict(cls.cv_results_).to_dict('records')
# Out:
# [{'mean_test_score': 0.5599999999999999,
#   'metric_balanced_accuracy': 0.5647222222222222,
#   'metric_precision': 0.5836825396825397,
#   'metric_recall': 0.4833333333333333,
#   'metric_f1': 0.519047619047619,
#   'mean_fit_time': 11.139771938323975,
#   'params': {'balancing:strategy': 'none',
#    'classifier:__choice__': 'random_forest',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'mean',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'standardize',
#    'feature_preprocessor:__choice__': 'no_preprocessing',
#    'classifier:random_forest:bootstrap': 'True',
#    'classifier:random_forest:criterion': 'gini',
#    'classifier:random_forest:max_depth': 'None',
#    'classifier:random_forest:max_features': 0.5,
#    'classifier:random_forest:max_leaf_nodes': 'None',
#    'classifier:random_forest:min_impurity_decrease': 0.0,
#    'classifier:random_forest:min_samples_leaf': 1,
#    'classifier:random_forest:min_samples_split': 2,
#    'classifier:random_forest:min_weight_fraction_leaf': 0.0,
#    'data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.01},
#   'rank_test_scores': 12,
#   'status': 'Success',
#   'budgets': 0.0,
#   'param_balancing:strategy': 'none',
#   'param_classifier:__choice__': 'random_forest',
#   'param_data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#   'param_data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#   'param_data_preprocessing:numerical_transformer:imputation:strategy': 'mean',
#   'param_data_preprocessing:numerical_transformer:rescaling:__choice__': 'standardize',
#   'param_feature_preprocessor:__choice__': 'no_preprocessing',
#   'param_classifier:adaboost:algorithm': nan,
#   'param_classifier:adaboost:learning_rate': nan,
#   'param_classifier:adaboost:max_depth': nan,
#   'param_classifier:adaboost:n_estimators': nan,
#   'param_classifier:bernoulli_nb:alpha': nan,
#   'param_classifier:bernoulli_nb:fit_prior': nan,
#   'param_classifier:decision_tree:criterion': nan,
#   'param_classifier:decision_tree:max_depth_factor': nan,
#   'param_classifier:decision_tree:max_features': nan,
#   'param_classifier:decision_tree:max_leaf_nodes': nan,
#   'param_classifier:decision_tree:min_impurity_decrease': nan,
#   'param_classifier:decision_tree:min_samples_leaf': nan,
#   'param_classifier:decision_tree:min_samples_split': nan,
#   'param_classifier:decision_tree:min_weight_fraction_leaf': nan,
#   'param_classifier:extra_trees:bootstrap': nan,
#   'param_classifier:extra_trees:criterion': nan,
#   'param_classifier:extra_trees:max_depth': nan,
#   'param_classifier:extra_trees:max_features': nan,
#   'param_classifier:extra_trees:max_leaf_nodes': nan,
#   'param_classifier:extra_trees:min_impurity_decrease': nan,
#   'param_classifier:extra_trees:min_samples_leaf': nan,
#   'param_classifier:extra_trees:min_samples_split': nan,
#   'param_classifier:extra_trees:min_weight_fraction_leaf': nan,
#   'param_classifier:gradient_boosting:early_stop': nan,
#   'param_classifier:gradient_boosting:l2_regularization': nan,
#   'param_classifier:gradient_boosting:learning_rate': nan,
#   'param_classifier:gradient_boosting:loss': nan,
#   'param_classifier:gradient_boosting:max_bins': nan,
#   'param_classifier:gradient_boosting:max_depth': nan,
#   'param_classifier:gradient_boosting:max_leaf_nodes': nan,
#   'param_classifier:gradient_boosting:min_samples_leaf': nan,
#   'param_classifier:gradient_boosting:scoring': nan,
#   'param_classifier:gradient_boosting:tol': nan,
#   'param_classifier:k_nearest_neighbors:n_neighbors': nan,
#   'param_classifier:k_nearest_neighbors:p': nan,
#   'param_classifier:k_nearest_neighbors:weights': nan,
#   'param_classifier:lda:shrinkage': nan,
#   'param_classifier:lda:tol': nan,
#   'param_classifier:liblinear_svc:C': nan,
#   'param_classifier:liblinear_svc:dual': nan,
#   'param_classifier:liblinear_svc:fit_intercept': nan,
#   'param_classifier:liblinear_svc:intercept_scaling': nan,
#   'param_classifier:liblinear_svc:loss': nan,
#   'param_classifier:liblinear_svc:multi_class': nan,
#   'param_classifier:liblinear_svc:penalty': nan,
#   'param_classifier:liblinear_svc:tol': nan,
#   'param_classifier:libsvm_svc:C': nan,
#   'param_classifier:libsvm_svc:gamma': nan,
#   'param_classifier:libsvm_svc:kernel': nan,
#   'param_classifier:libsvm_svc:max_iter': nan,
#   'param_classifier:libsvm_svc:shrinking': nan,
#   'param_classifier:libsvm_svc:tol': nan,
#   'param_classifier:mlp:activation': nan,
#   'param_classifier:mlp:alpha': nan,
#   'param_classifier:mlp:batch_size': nan,
#   'param_classifier:mlp:beta_1': nan,
#   'param_classifier:mlp:beta_2': nan,
#   'param_classifier:mlp:early_stopping': nan,
#   'param_classifier:mlp:epsilon': nan,
#   'param_classifier:mlp:hidden_layer_depth': nan,
#   'param_classifier:mlp:learning_rate_init': nan,
#   'param_classifier:mlp:n_iter_no_change': nan,
#   'param_classifier:mlp:num_nodes_per_layer': nan,
#   'param_classifier:mlp:shuffle': nan,
#   'param_classifier:mlp:solver': nan,
#   'param_classifier:mlp:tol': nan,
#   'param_classifier:multinomial_nb:alpha': nan,
#   'param_classifier:multinomial_nb:fit_prior': nan,
#   'param_classifier:passive_aggressive:C': nan,
#   'param_classifier:passive_aggressive:average': nan,
#   'param_classifier:passive_aggressive:fit_intercept': nan,
#   'param_classifier:passive_aggressive:loss': nan,
#   'param_classifier:passive_aggressive:tol': nan,
#   'param_classifier:qda:reg_param': nan,
#   'param_classifier:random_forest:bootstrap': 'True',
#   'param_classifier:random_forest:criterion': 'gini',
#   'param_classifier:random_forest:max_depth': 'None',
#   'param_classifier:random_forest:max_features': 0.5,
#   'param_classifier:random_forest:max_leaf_nodes': 'None',
#   'param_classifier:random_forest:min_impurity_decrease': 0.0,
#   'param_classifier:random_forest:min_samples_leaf': 1.0,
#   'param_classifier:random_forest:min_samples_split': 2.0,
#   'param_classifier:random_forest:min_weight_fraction_leaf': 0.0,
#   'param_classifier:sgd:alpha': nan,
#   'param_classifier:sgd:average': nan,
#   'param_classifier:sgd:fit_intercept': nan,
#   'param_classifier:sgd:learning_rate': nan,
#   'param_classifier:sgd:loss': nan,
#   'param_classifier:sgd:penalty': nan,
#   'param_classifier:sgd:tol': nan,
#   'param_data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.01,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_max': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_min': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:criterion': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_depth': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': nan,
#   'param_feature_preprocessor:fast_ica:algorithm': nan,
#   'param_feature_preprocessor:fast_ica:fun': nan,
#   'param_feature_preprocessor:fast_ica:whiten': nan,
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_depth': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': nan,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': nan,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan},
#  {'mean_test_score': 0.5399999999999999,
#   'metric_balanced_accuracy': 0.53875,
#   'metric_precision': 0.5442857142857143,
#   'metric_recall': 0.4786111111111111,
#   'metric_f1': 0.5093333333333332,
#   'mean_fit_time': 12.03387999534607,
#   'params': {'balancing:strategy': 'weighting',
#    'classifier:__choice__': 'extra_trees',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'no_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'normalize',
#    'feature_preprocessor:__choice__': 'extra_trees_preproc_for_classification',
#    'classifier:extra_trees:bootstrap': 'False',
#    'classifier:extra_trees:criterion': 'gini',
#    'classifier:extra_trees:max_depth': 'None',
#    'classifier:extra_trees:max_features': 0.9292309396985746,
#    'classifier:extra_trees:max_leaf_nodes': 'None',
#    'classifier:extra_trees:min_impurity_decrease': 0.0,
#    'classifier:extra_trees:min_samples_leaf': 1,
#    'classifier:extra_trees:min_samples_split': 10,
#    'classifier:extra_trees:min_weight_fraction_leaf': 0.0,
#    'data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.032719158639429445,
#    'feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': 'False',
#    'feature_preprocessor:extra_trees_preproc_for_classification:criterion': 'entropy',
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_depth': 'None',
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_features': 0.9929881254946676,
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None',
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 1,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': 2,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0,
#    'feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': 100},
#   'rank_test_scores': 17,
#   'status': 'Success',
#   'budgets': 0.0,
#   'param_balancing:strategy': 'weighting',
#   'param_classifier:__choice__': 'extra_trees',
#   'param_data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'no_encoding',
#   'param_data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#   'param_data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#   'param_data_preprocessing:numerical_transformer:rescaling:__choice__': 'normalize',
#   'param_feature_preprocessor:__choice__': 'extra_trees_preproc_for_classification',
#   'param_classifier:adaboost:algorithm': nan,
#   'param_classifier:adaboost:learning_rate': nan,
#   'param_classifier:adaboost:max_depth': nan,
#   'param_classifier:adaboost:n_estimators': nan,
#   'param_classifier:bernoulli_nb:alpha': nan,
#   'param_classifier:bernoulli_nb:fit_prior': nan,
#   'param_classifier:decision_tree:criterion': nan,
#   'param_classifier:decision_tree:max_depth_factor': nan,
#   'param_classifier:decision_tree:max_features': nan,
#   'param_classifier:decision_tree:max_leaf_nodes': nan,
#   'param_classifier:decision_tree:min_impurity_decrease': nan,
#   'param_classifier:decision_tree:min_samples_leaf': nan,
#   'param_classifier:decision_tree:min_samples_split': nan,
#   'param_classifier:decision_tree:min_weight_fraction_leaf': nan,
#   'param_classifier:extra_trees:bootstrap': 'False',
#   'param_classifier:extra_trees:criterion': 'gini',
#   'param_classifier:extra_trees:max_depth': 'None',
#   'param_classifier:extra_trees:max_features': 0.9292309396985746,
#   'param_classifier:extra_trees:max_leaf_nodes': 'None',
#   'param_classifier:extra_trees:min_impurity_decrease': 0.0,
#   'param_classifier:extra_trees:min_samples_leaf': 1.0,
#   'param_classifier:extra_trees:min_samples_split': 10.0,
#   'param_classifier:extra_trees:min_weight_fraction_leaf': 0.0,
#   'param_classifier:gradient_boosting:early_stop': nan,
#   'param_classifier:gradient_boosting:l2_regularization': nan,
#   'param_classifier:gradient_boosting:learning_rate': nan,
#   'param_classifier:gradient_boosting:loss': nan,
#   'param_classifier:gradient_boosting:max_bins': nan,
#   'param_classifier:gradient_boosting:max_depth': nan,
#   'param_classifier:gradient_boosting:max_leaf_nodes': nan,
#   'param_classifier:gradient_boosting:min_samples_leaf': nan,
#   'param_classifier:gradient_boosting:scoring': nan,
#   'param_classifier:gradient_boosting:tol': nan,
#   'param_classifier:k_nearest_neighbors:n_neighbors': nan,
#   'param_classifier:k_nearest_neighbors:p': nan,
#   'param_classifier:k_nearest_neighbors:weights': nan,
#   'param_classifier:lda:shrinkage': nan,
#   'param_classifier:lda:tol': nan,
#   'param_classifier:liblinear_svc:C': nan,
#   'param_classifier:liblinear_svc:dual': nan,
#   'param_classifier:liblinear_svc:fit_intercept': nan,
#   'param_classifier:liblinear_svc:intercept_scaling': nan,
#   'param_classifier:liblinear_svc:loss': nan,
#   'param_classifier:liblinear_svc:multi_class': nan,
#   'param_classifier:liblinear_svc:penalty': nan,
#   'param_classifier:liblinear_svc:tol': nan,
#   'param_classifier:libsvm_svc:C': nan,
#   'param_classifier:libsvm_svc:gamma': nan,
#   'param_classifier:libsvm_svc:kernel': nan,
#   'param_classifier:libsvm_svc:max_iter': nan,
#   'param_classifier:libsvm_svc:shrinking': nan,
#   'param_classifier:libsvm_svc:tol': nan,
#   'param_classifier:mlp:activation': nan,
#   'param_classifier:mlp:alpha': nan,
#   'param_classifier:mlp:batch_size': nan,
#   'param_classifier:mlp:beta_1': nan,
#   'param_classifier:mlp:beta_2': nan,
#   'param_classifier:mlp:early_stopping': nan,
#   'param_classifier:mlp:epsilon': nan,
#   'param_classifier:mlp:hidden_layer_depth': nan,
#   'param_classifier:mlp:learning_rate_init': nan,
#   'param_classifier:mlp:n_iter_no_change': nan,
#   'param_classifier:mlp:num_nodes_per_layer': nan,
#   'param_classifier:mlp:shuffle': nan,
#   'param_classifier:mlp:solver': nan,
#   'param_classifier:mlp:tol': nan,
#   'param_classifier:multinomial_nb:alpha': nan,
#   'param_classifier:multinomial_nb:fit_prior': nan,
#   'param_classifier:passive_aggressive:C': nan,
#   'param_classifier:passive_aggressive:average': nan,
#   'param_classifier:passive_aggressive:fit_intercept': nan,
#   'param_classifier:passive_aggressive:loss': nan,
#   'param_classifier:passive_aggressive:tol': nan,
#   'param_classifier:qda:reg_param': nan,
#   'param_classifier:random_forest:bootstrap': nan,
#   'param_classifier:random_forest:criterion': nan,
#   'param_classifier:random_forest:max_depth': nan,
#   'param_classifier:random_forest:max_features': nan,
#   'param_classifier:random_forest:max_leaf_nodes': nan,
#   'param_classifier:random_forest:min_impurity_decrease': nan,
#   'param_classifier:random_forest:min_samples_leaf': nan,
#   'param_classifier:random_forest:min_samples_split': nan,
#   'param_classifier:random_forest:min_weight_fraction_leaf': nan,
#   'param_classifier:sgd:alpha': nan,
#   'param_classifier:sgd:average': nan,
#   'param_classifier:sgd:fit_intercept': nan,
#   'param_classifier:sgd:learning_rate': nan,
#   'param_classifier:sgd:loss': nan,
#   'param_classifier:sgd:penalty': nan,
#   'param_classifier:sgd:tol': nan,
#   'param_data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.032719158639429445,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_max': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_min': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': 'False',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:criterion': 'entropy',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_depth': 'None',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': 0.9929881254946676,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 1.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': 2.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': 100.0,
#   'param_feature_preprocessor:fast_ica:algorithm': nan,
#   'param_feature_preprocessor:fast_ica:fun': nan,
#   'param_feature_preprocessor:fast_ica:whiten': nan,
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_depth': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': nan,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': nan,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan},
#  {'mean_test_score': 0.54,
#   'metric_balanced_accuracy': 0.54,
#   'metric_precision': 0.54,
#   'metric_recall': 0.5211111111111111,
#   'metric_f1': 0.53,
#   'mean_fit_time': 31.47611713409424,
#   'params': {'balancing:strategy': 'none',
#    'classifier:__choice__': 'gradient_boosting',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'standardize',
#    'feature_preprocessor:__choice__': 'extra_trees_preproc_for_classification',
#    'classifier:gradient_boosting:early_stop': 'train',
#    'classifier:gradient_boosting:l2_regularization': 0.4635442279519353,
#    'classifier:gradient_boosting:learning_rate': 0.09809681787962342,
#    'classifier:gradient_boosting:loss': 'auto',
#    'classifier:gradient_boosting:max_bins': 255,
#    'classifier:gradient_boosting:max_depth': 'None',
#    'classifier:gradient_boosting:max_leaf_nodes': 328,
#    'classifier:gradient_boosting:min_samples_leaf': 2,
#    'classifier:gradient_boosting:scoring': 'loss',
#    'classifier:gradient_boosting:tol': 1e-07,
#    'data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.0208475757765491,
#    'feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': 'False',
#    'feature_preprocessor:extra_trees_preproc_for_classification:criterion': 'entropy',
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_depth': 'None',
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_features': 0.989729761503726,
#    'feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None',
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 19,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': 5,
#    'feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0,
#    'feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': 100,
#    'classifier:gradient_boosting:n_iter_no_change': 2},
#   'rank_test_scores': 15,
#   'status': 'Success',
#   'budgets': 0.0,
#   'param_balancing:strategy': 'none',
#   'param_classifier:__choice__': 'gradient_boosting',
#   'param_data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#   'param_data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'minority_coalescer',
#   'param_data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#   'param_data_preprocessing:numerical_transformer:rescaling:__choice__': 'standardize',
#   'param_feature_preprocessor:__choice__': 'extra_trees_preproc_for_classification',
#   'param_classifier:adaboost:algorithm': nan,
#   'param_classifier:adaboost:learning_rate': nan,
#   'param_classifier:adaboost:max_depth': nan,
#   'param_classifier:adaboost:n_estimators': nan,
#   'param_classifier:bernoulli_nb:alpha': nan,
#   'param_classifier:bernoulli_nb:fit_prior': nan,
#   'param_classifier:decision_tree:criterion': nan,
#   'param_classifier:decision_tree:max_depth_factor': nan,
#   'param_classifier:decision_tree:max_features': nan,
#   'param_classifier:decision_tree:max_leaf_nodes': nan,
#   'param_classifier:decision_tree:min_impurity_decrease': nan,
#   'param_classifier:decision_tree:min_samples_leaf': nan,
#   'param_classifier:decision_tree:min_samples_split': nan,
#   'param_classifier:decision_tree:min_weight_fraction_leaf': nan,
#   'param_classifier:extra_trees:bootstrap': nan,
#   'param_classifier:extra_trees:criterion': nan,
#   'param_classifier:extra_trees:max_depth': nan,
#   'param_classifier:extra_trees:max_features': nan,
#   'param_classifier:extra_trees:max_leaf_nodes': nan,
#   'param_classifier:extra_trees:min_impurity_decrease': nan,
#   'param_classifier:extra_trees:min_samples_leaf': nan,
#   'param_classifier:extra_trees:min_samples_split': nan,
#   'param_classifier:extra_trees:min_weight_fraction_leaf': nan,
#   'param_classifier:gradient_boosting:early_stop': 'train',
#   'param_classifier:gradient_boosting:l2_regularization': 0.4635442279519353,
#   'param_classifier:gradient_boosting:learning_rate': 0.09809681787962342,
#   'param_classifier:gradient_boosting:loss': 'auto',
#   'param_classifier:gradient_boosting:max_bins': 255.0,
#   'param_classifier:gradient_boosting:max_depth': 'None',
#   'param_classifier:gradient_boosting:max_leaf_nodes': 328.0,
#   'param_classifier:gradient_boosting:min_samples_leaf': 2.0,
#   'param_classifier:gradient_boosting:scoring': 'loss',
#   'param_classifier:gradient_boosting:tol': 1e-07,
#   'param_classifier:k_nearest_neighbors:n_neighbors': nan,
#   'param_classifier:k_nearest_neighbors:p': nan,
#   'param_classifier:k_nearest_neighbors:weights': nan,
#   'param_classifier:lda:shrinkage': nan,
#   'param_classifier:lda:tol': nan,
#   'param_classifier:liblinear_svc:C': nan,
#   'param_classifier:liblinear_svc:dual': nan,
#   'param_classifier:liblinear_svc:fit_intercept': nan,
#   'param_classifier:liblinear_svc:intercept_scaling': nan,
#   'param_classifier:liblinear_svc:loss': nan,
#   'param_classifier:liblinear_svc:multi_class': nan,
#   'param_classifier:liblinear_svc:penalty': nan,
#   'param_classifier:liblinear_svc:tol': nan,
#   'param_classifier:libsvm_svc:C': nan,
#   'param_classifier:libsvm_svc:gamma': nan,
#   'param_classifier:libsvm_svc:kernel': nan,
#   'param_classifier:libsvm_svc:max_iter': nan,
#   'param_classifier:libsvm_svc:shrinking': nan,
#   'param_classifier:libsvm_svc:tol': nan,
#   'param_classifier:mlp:activation': nan,
#   'param_classifier:mlp:alpha': nan,
#   'param_classifier:mlp:batch_size': nan,
#   'param_classifier:mlp:beta_1': nan,
#   'param_classifier:mlp:beta_2': nan,
#   'param_classifier:mlp:early_stopping': nan,
#   'param_classifier:mlp:epsilon': nan,
#   'param_classifier:mlp:hidden_layer_depth': nan,
#   'param_classifier:mlp:learning_rate_init': nan,
#   'param_classifier:mlp:n_iter_no_change': nan,
#   'param_classifier:mlp:num_nodes_per_layer': nan,
#   'param_classifier:mlp:shuffle': nan,
#   'param_classifier:mlp:solver': nan,
#   'param_classifier:mlp:tol': nan,
#   'param_classifier:multinomial_nb:alpha': nan,
#   'param_classifier:multinomial_nb:fit_prior': nan,
#   'param_classifier:passive_aggressive:C': nan,
#   'param_classifier:passive_aggressive:average': nan,
#   'param_classifier:passive_aggressive:fit_intercept': nan,
#   'param_classifier:passive_aggressive:loss': nan,
#   'param_classifier:passive_aggressive:tol': nan,
#   'param_classifier:qda:reg_param': nan,
#   'param_classifier:random_forest:bootstrap': nan,
#   'param_classifier:random_forest:criterion': nan,
#   'param_classifier:random_forest:max_depth': nan,
#   'param_classifier:random_forest:max_features': nan,
#   'param_classifier:random_forest:max_leaf_nodes': nan,
#   'param_classifier:random_forest:min_impurity_decrease': nan,
#   'param_classifier:random_forest:min_samples_leaf': nan,
#   'param_classifier:random_forest:min_samples_split': nan,
#   'param_classifier:random_forest:min_weight_fraction_leaf': nan,
#   'param_classifier:sgd:alpha': nan,
#   'param_classifier:sgd:average': nan,
#   'param_classifier:sgd:fit_intercept': nan,
#   'param_classifier:sgd:learning_rate': nan,
#   'param_classifier:sgd:loss': nan,
#   'param_classifier:sgd:penalty': nan,
#   'param_classifier:sgd:tol': nan,
#   'param_data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': 0.0208475757765491,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_max': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_min': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': 'False',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:criterion': 'entropy',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_depth': 'None',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': 0.989729761503726,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': 'None',
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': 0.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': 19.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': 5.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': 0.0,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': 100.0,
#   'param_feature_preprocessor:fast_ica:algorithm': nan,
#   'param_feature_preprocessor:fast_ica:fun': nan,
#   'param_feature_preprocessor:fast_ica:whiten': nan,
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_depth': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': nan,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': 2.0,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan},
#  {'mean_test_score': 0.0,
#   'metric_balanced_accuracy': nan,
#   'metric_precision': nan,
#   'metric_recall': nan,
#   'metric_f1': nan,
#   'mean_fit_time': 3.0755741596221924,
#   'params': {'balancing:strategy': 'weighting',
#    'classifier:__choice__': 'k_nearest_neighbors',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'no_coalescense',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'mean',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'normalize',
#    'feature_preprocessor:__choice__': 'fast_ica',
#    'classifier:k_nearest_neighbors:n_neighbors': 1,
#    'classifier:k_nearest_neighbors:p': 1,
#    'classifier:k_nearest_neighbors:weights': 'uniform',
#    'feature_preprocessor:fast_ica:algorithm': 'deflation',
#    'feature_preprocessor:fast_ica:fun': 'cube',
#    'feature_preprocessor:fast_ica:whiten': 'False'},
#   'rank_test_scores': 23,
#   'status': 'Crash',
#   'budgets': 0.0,
#   'param_balancing:strategy': 'weighting',
#   'param_classifier:__choice__': 'k_nearest_neighbors',
#   'param_data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'one_hot_encoding',
#   'param_data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'no_coalescense',
#   'param_data_preprocessing:numerical_transformer:imputation:strategy': 'mean',
#   'param_data_preprocessing:numerical_transformer:rescaling:__choice__': 'normalize',
#   'param_feature_preprocessor:__choice__': 'fast_ica',
#   'param_classifier:adaboost:algorithm': nan,
#   'param_classifier:adaboost:learning_rate': nan,
#   'param_classifier:adaboost:max_depth': nan,
#   'param_classifier:adaboost:n_estimators': nan,
#   'param_classifier:bernoulli_nb:alpha': nan,
#   'param_classifier:bernoulli_nb:fit_prior': nan,
#   'param_classifier:decision_tree:criterion': nan,
#   'param_classifier:decision_tree:max_depth_factor': nan,
#   'param_classifier:decision_tree:max_features': nan,
#   'param_classifier:decision_tree:max_leaf_nodes': nan,
#   'param_classifier:decision_tree:min_impurity_decrease': nan,
#   'param_classifier:decision_tree:min_samples_leaf': nan,
#   'param_classifier:decision_tree:min_samples_split': nan,
#   'param_classifier:decision_tree:min_weight_fraction_leaf': nan,
#   'param_classifier:extra_trees:bootstrap': nan,
#   'param_classifier:extra_trees:criterion': nan,
#   'param_classifier:extra_trees:max_depth': nan,
#   'param_classifier:extra_trees:max_features': nan,
#   'param_classifier:extra_trees:max_leaf_nodes': nan,
#   'param_classifier:extra_trees:min_impurity_decrease': nan,
#   'param_classifier:extra_trees:min_samples_leaf': nan,
#   'param_classifier:extra_trees:min_samples_split': nan,
#   'param_classifier:extra_trees:min_weight_fraction_leaf': nan,
#   'param_classifier:gradient_boosting:early_stop': nan,
#   'param_classifier:gradient_boosting:l2_regularization': nan,
#   'param_classifier:gradient_boosting:learning_rate': nan,
#   'param_classifier:gradient_boosting:loss': nan,
#   'param_classifier:gradient_boosting:max_bins': nan,
#   'param_classifier:gradient_boosting:max_depth': nan,
#   'param_classifier:gradient_boosting:max_leaf_nodes': nan,
#   'param_classifier:gradient_boosting:min_samples_leaf': nan,
#   'param_classifier:gradient_boosting:scoring': nan,
#   'param_classifier:gradient_boosting:tol': nan,
#   'param_classifier:k_nearest_neighbors:n_neighbors': 1.0,
#   'param_classifier:k_nearest_neighbors:p': 1.0,
#   'param_classifier:k_nearest_neighbors:weights': 'uniform',
#   'param_classifier:lda:shrinkage': nan,
#   'param_classifier:lda:tol': nan,
#   'param_classifier:liblinear_svc:C': nan,
#   'param_classifier:liblinear_svc:dual': nan,
#   'param_classifier:liblinear_svc:fit_intercept': nan,
#   'param_classifier:liblinear_svc:intercept_scaling': nan,
#   'param_classifier:liblinear_svc:loss': nan,
#   'param_classifier:liblinear_svc:multi_class': nan,
#   'param_classifier:liblinear_svc:penalty': nan,
#   'param_classifier:liblinear_svc:tol': nan,
#   'param_classifier:libsvm_svc:C': nan,
#   'param_classifier:libsvm_svc:gamma': nan,
#   'param_classifier:libsvm_svc:kernel': nan,
#   'param_classifier:libsvm_svc:max_iter': nan,
#   'param_classifier:libsvm_svc:shrinking': nan,
#   'param_classifier:libsvm_svc:tol': nan,
#   'param_classifier:mlp:activation': nan,
#   'param_classifier:mlp:alpha': nan,
#   'param_classifier:mlp:batch_size': nan,
#   'param_classifier:mlp:beta_1': nan,
#   'param_classifier:mlp:beta_2': nan,
#   'param_classifier:mlp:early_stopping': nan,
#   'param_classifier:mlp:epsilon': nan,
#   'param_classifier:mlp:hidden_layer_depth': nan,
#   'param_classifier:mlp:learning_rate_init': nan,
#   'param_classifier:mlp:n_iter_no_change': nan,
#   'param_classifier:mlp:num_nodes_per_layer': nan,
#   'param_classifier:mlp:shuffle': nan,
#   'param_classifier:mlp:solver': nan,
#   'param_classifier:mlp:tol': nan,
#   'param_classifier:multinomial_nb:alpha': nan,
#   'param_classifier:multinomial_nb:fit_prior': nan,
#   'param_classifier:passive_aggressive:C': nan,
#   'param_classifier:passive_aggressive:average': nan,
#   'param_classifier:passive_aggressive:fit_intercept': nan,
#   'param_classifier:passive_aggressive:loss': nan,
#   'param_classifier:passive_aggressive:tol': nan,
#   'param_classifier:qda:reg_param': nan,
#   'param_classifier:random_forest:bootstrap': nan,
#   'param_classifier:random_forest:criterion': nan,
#   'param_classifier:random_forest:max_depth': nan,
#   'param_classifier:random_forest:max_features': nan,
#   'param_classifier:random_forest:max_leaf_nodes': nan,
#   'param_classifier:random_forest:min_impurity_decrease': nan,
#   'param_classifier:random_forest:min_samples_leaf': nan,
#   'param_classifier:random_forest:min_samples_split': nan,
#   'param_classifier:random_forest:min_weight_fraction_leaf': nan,
#   'param_classifier:sgd:alpha': nan,
#   'param_classifier:sgd:average': nan,
#   'param_classifier:sgd:fit_intercept': nan,
#   'param_classifier:sgd:learning_rate': nan,
#   'param_classifier:sgd:loss': nan,
#   'param_classifier:sgd:penalty': nan,
#   'param_classifier:sgd:tol': nan,
#   'param_data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_max': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_min': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:criterion': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_depth': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': nan,
#   'param_feature_preprocessor:fast_ica:algorithm': 'deflation',
#   'param_feature_preprocessor:fast_ica:fun': 'cube',
#   'param_feature_preprocessor:fast_ica:whiten': 'False',
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_depth': nan,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': nan,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': nan,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': nan,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan},
#  {'mean_test_score': 0.5599999999999999,
#   'metric_balanced_accuracy': 0.5659722222222222,
#   'metric_precision': 0.5732121212121212,
#   'metric_recall': 0.6036111111111111,
#   'metric_f1': 0.5736140350877192,
#   'mean_fit_time': 12.488341093063354,
#   'params': {'balancing:strategy': 'weighting',
#    'classifier:__choice__': 'random_forest',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'no_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'no_coalescense',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'most_frequent',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'standardize',
#    'feature_preprocessor:__choice__': 'extra_trees_preproc_for_classification',
#    'classifier:random_forest:bootstrap': 'True',
#    'classifier:random_forest:criterion': 'gini',
#    'classifier:random_forest:max_depth': 'None',
#    'classifier:random_forest:max_features': 0.43999367631975456,
# ...
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': nan,
#   'param_feature_preprocessor:fast_ica:algorithm': nan,
#   'param_feature_preprocessor:fast_ica:fun': nan,
#   'param_feature_preprocessor:fast_ica:whiten': nan,
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': 'True',
#   'param_feature_preprocessor:random_trees_embedding:max_depth': 3.0,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': 'None',
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': 17.0,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': 12.0,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': 38.0,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': nan,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan},
#  {'mean_test_score': 0.0,
#   'metric_balanced_accuracy': nan,
#   'metric_precision': nan,
#   'metric_recall': nan,
#   'metric_f1': nan,
#   'mean_fit_time': 2.1706302165985107,
#   'params': {'balancing:strategy': 'none',
#    'classifier:__choice__': 'random_forest',
#    'data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'no_encoding',
#    'data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'no_coalescense',
#    'data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#    'data_preprocessing:numerical_transformer:rescaling:__choice__': 'quantile_transformer',
#    'feature_preprocessor:__choice__': 'random_trees_embedding',
#    'classifier:random_forest:bootstrap': 'False',
#    'classifier:random_forest:criterion': 'entropy',
#    'classifier:random_forest:max_depth': 'None',
#    'classifier:random_forest:max_features': 0.7432602952286883,
#    'classifier:random_forest:max_leaf_nodes': 'None',
#    'classifier:random_forest:min_impurity_decrease': 0.0,
#    'classifier:random_forest:min_samples_leaf': 8,
#    'classifier:random_forest:min_samples_split': 11,
#    'classifier:random_forest:min_weight_fraction_leaf': 0.0,
#    'data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': 1649,
#    'data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': 'normal',
#    'feature_preprocessor:random_trees_embedding:bootstrap': 'True',
#    'feature_preprocessor:random_trees_embedding:max_depth': 7,
#    'feature_preprocessor:random_trees_embedding:max_leaf_nodes': 'None',
#    'feature_preprocessor:random_trees_embedding:min_samples_leaf': 17,
#    'feature_preprocessor:random_trees_embedding:min_samples_split': 10,
#    'feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0,
#    'feature_preprocessor:random_trees_embedding:n_estimators': 30},
#   'rank_test_scores': 23,
#   'status': 'Timeout',
#   'budgets': 0.0,
#   'param_balancing:strategy': 'none',
#   'param_classifier:__choice__': 'random_forest',
#   'param_data_preprocessing:categorical_transformer:categorical_encoding:__choice__': 'no_encoding',
#   'param_data_preprocessing:categorical_transformer:category_coalescence:__choice__': 'no_coalescense',
#   'param_data_preprocessing:numerical_transformer:imputation:strategy': 'median',
#   'param_data_preprocessing:numerical_transformer:rescaling:__choice__': 'quantile_transformer',
#   'param_feature_preprocessor:__choice__': 'random_trees_embedding',
#   'param_classifier:adaboost:algorithm': nan,
#   'param_classifier:adaboost:learning_rate': nan,
#   'param_classifier:adaboost:max_depth': nan,
#   'param_classifier:adaboost:n_estimators': nan,
#   'param_classifier:bernoulli_nb:alpha': nan,
#   'param_classifier:bernoulli_nb:fit_prior': nan,
#   'param_classifier:decision_tree:criterion': nan,
#   'param_classifier:decision_tree:max_depth_factor': nan,
#   'param_classifier:decision_tree:max_features': nan,
#   'param_classifier:decision_tree:max_leaf_nodes': nan,
#   'param_classifier:decision_tree:min_impurity_decrease': nan,
#   'param_classifier:decision_tree:min_samples_leaf': nan,
#   'param_classifier:decision_tree:min_samples_split': nan,
#   'param_classifier:decision_tree:min_weight_fraction_leaf': nan,
#   'param_classifier:extra_trees:bootstrap': nan,
#   'param_classifier:extra_trees:criterion': nan,
#   'param_classifier:extra_trees:max_depth': nan,
#   'param_classifier:extra_trees:max_features': nan,
#   'param_classifier:extra_trees:max_leaf_nodes': nan,
#   'param_classifier:extra_trees:min_impurity_decrease': nan,
#   'param_classifier:extra_trees:min_samples_leaf': nan,
#   'param_classifier:extra_trees:min_samples_split': nan,
#   'param_classifier:extra_trees:min_weight_fraction_leaf': nan,
#   'param_classifier:gradient_boosting:early_stop': nan,
#   'param_classifier:gradient_boosting:l2_regularization': nan,
#   'param_classifier:gradient_boosting:learning_rate': nan,
#   'param_classifier:gradient_boosting:loss': nan,
#   'param_classifier:gradient_boosting:max_bins': nan,
#   'param_classifier:gradient_boosting:max_depth': nan,
#   'param_classifier:gradient_boosting:max_leaf_nodes': nan,
#   'param_classifier:gradient_boosting:min_samples_leaf': nan,
#   'param_classifier:gradient_boosting:scoring': nan,
#   'param_classifier:gradient_boosting:tol': nan,
#   'param_classifier:k_nearest_neighbors:n_neighbors': nan,
#   'param_classifier:k_nearest_neighbors:p': nan,
#   'param_classifier:k_nearest_neighbors:weights': nan,
#   'param_classifier:lda:shrinkage': nan,
#   'param_classifier:lda:tol': nan,
#   'param_classifier:liblinear_svc:C': nan,
#   'param_classifier:liblinear_svc:dual': nan,
#   'param_classifier:liblinear_svc:fit_intercept': nan,
#   'param_classifier:liblinear_svc:intercept_scaling': nan,
#   'param_classifier:liblinear_svc:loss': nan,
#   'param_classifier:liblinear_svc:multi_class': nan,
#   'param_classifier:liblinear_svc:penalty': nan,
#   'param_classifier:liblinear_svc:tol': nan,
#   'param_classifier:libsvm_svc:C': nan,
#   'param_classifier:libsvm_svc:gamma': nan,
#   'param_classifier:libsvm_svc:kernel': nan,
#   'param_classifier:libsvm_svc:max_iter': nan,
#   'param_classifier:libsvm_svc:shrinking': nan,
#   'param_classifier:libsvm_svc:tol': nan,
#   'param_classifier:mlp:activation': nan,
#   'param_classifier:mlp:alpha': nan,
#   'param_classifier:mlp:batch_size': nan,
#   'param_classifier:mlp:beta_1': nan,
#   'param_classifier:mlp:beta_2': nan,
#   'param_classifier:mlp:early_stopping': nan,
#   'param_classifier:mlp:epsilon': nan,
#   'param_classifier:mlp:hidden_layer_depth': nan,
#   'param_classifier:mlp:learning_rate_init': nan,
#   'param_classifier:mlp:n_iter_no_change': nan,
#   'param_classifier:mlp:num_nodes_per_layer': nan,
#   'param_classifier:mlp:shuffle': nan,
#   'param_classifier:mlp:solver': nan,
#   'param_classifier:mlp:tol': nan,
#   'param_classifier:multinomial_nb:alpha': nan,
#   'param_classifier:multinomial_nb:fit_prior': nan,
#   'param_classifier:passive_aggressive:C': nan,
#   'param_classifier:passive_aggressive:average': nan,
#   'param_classifier:passive_aggressive:fit_intercept': nan,
#   'param_classifier:passive_aggressive:loss': nan,
#   'param_classifier:passive_aggressive:tol': nan,
#   'param_classifier:qda:reg_param': nan,
#   'param_classifier:random_forest:bootstrap': 'False',
#   'param_classifier:random_forest:criterion': 'entropy',
#   'param_classifier:random_forest:max_depth': 'None',
#   'param_classifier:random_forest:max_features': 0.7432602952286883,
#   'param_classifier:random_forest:max_leaf_nodes': 'None',
#   'param_classifier:random_forest:min_impurity_decrease': 0.0,
#   'param_classifier:random_forest:min_samples_leaf': 8.0,
#   'param_classifier:random_forest:min_samples_split': 11.0,
#   'param_classifier:random_forest:min_weight_fraction_leaf': 0.0,
#   'param_classifier:sgd:alpha': nan,
#   'param_classifier:sgd:average': nan,
#   'param_classifier:sgd:fit_intercept': nan,
#   'param_classifier:sgd:learning_rate': nan,
#   'param_classifier:sgd:loss': nan,
#   'param_classifier:sgd:penalty': nan,
#   'param_classifier:sgd:tol': nan,
#   'param_data_preprocessing:categorical_transformer:category_coalescence:minority_coalescer:minimum_fraction': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:n_quantiles': 1649.0,
#   'param_data_preprocessing:numerical_transformer:rescaling:quantile_transformer:output_distribution': 'normal',
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_max': nan,
#   'param_data_preprocessing:numerical_transformer:rescaling:robust_scaler:q_min': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:bootstrap': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:criterion': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_depth': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_features': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:max_leaf_nodes': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_impurity_decrease': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_samples_split': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:min_weight_fraction_leaf': nan,
#   'param_feature_preprocessor:extra_trees_preproc_for_classification:n_estimators': nan,
#   'param_feature_preprocessor:fast_ica:algorithm': nan,
#   'param_feature_preprocessor:fast_ica:fun': nan,
#   'param_feature_preprocessor:fast_ica:whiten': nan,
#   'param_feature_preprocessor:feature_agglomeration:affinity': nan,
#   'param_feature_preprocessor:feature_agglomeration:linkage': nan,
#   'param_feature_preprocessor:feature_agglomeration:n_clusters': nan,
#   'param_feature_preprocessor:feature_agglomeration:pooling_func': nan,
#   'param_feature_preprocessor:kernel_pca:kernel': nan,
#   'param_feature_preprocessor:kernel_pca:n_components': nan,
#   'param_feature_preprocessor:kitchen_sinks:gamma': nan,
#   'param_feature_preprocessor:kitchen_sinks:n_components': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:C': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:dual': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:fit_intercept': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:intercept_scaling': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:loss': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:multi_class': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:penalty': nan,
#   'param_feature_preprocessor:liblinear_svc_preprocessor:tol': nan,
#   'param_feature_preprocessor:nystroem_sampler:kernel': nan,
#   'param_feature_preprocessor:nystroem_sampler:n_components': nan,
#   'param_feature_preprocessor:pca:keep_variance': nan,
#   'param_feature_preprocessor:pca:whiten': nan,
#   'param_feature_preprocessor:polynomial:degree': nan,
#   'param_feature_preprocessor:polynomial:include_bias': nan,
#   'param_feature_preprocessor:polynomial:interaction_only': nan,
#   'param_feature_preprocessor:random_trees_embedding:bootstrap': 'True',
#   'param_feature_preprocessor:random_trees_embedding:max_depth': 7.0,
#   'param_feature_preprocessor:random_trees_embedding:max_leaf_nodes': 'None',
#   'param_feature_preprocessor:random_trees_embedding:min_samples_leaf': 17.0,
#   'param_feature_preprocessor:random_trees_embedding:min_samples_split': 10.0,
#   'param_feature_preprocessor:random_trees_embedding:min_weight_fraction_leaf': 1.0,
#   'param_feature_preprocessor:random_trees_embedding:n_estimators': 30.0,
#   'param_feature_preprocessor:select_percentile_classification:percentile': nan,
#   'param_feature_preprocessor:select_percentile_classification:score_func': nan,
#   'param_feature_preprocessor:select_rates_classification:alpha': nan,
#   'param_feature_preprocessor:select_rates_classification:score_func': nan,
#   'param_classifier:gradient_boosting:n_iter_no_change': nan,
#   'param_classifier:gradient_boosting:validation_fraction': nan,
#   'param_classifier:lda:shrinkage_factor': nan,
#   'param_classifier:libsvm_svc:coef0': nan,
#   'param_classifier:libsvm_svc:degree': nan,
#   'param_classifier:mlp:validation_fraction': nan,
#   'param_classifier:sgd:epsilon': nan,
#   'param_classifier:sgd:eta0': nan,
#   'param_classifier:sgd:l1_ratio': nan,
#   'param_classifier:sgd:power_t': nan,
#   'param_feature_preprocessor:fast_ica:n_components': nan,
#   'param_feature_preprocessor:kernel_pca:coef0': nan,
#   'param_feature_preprocessor:kernel_pca:degree': nan,
#   'param_feature_preprocessor:kernel_pca:gamma': nan,
#   'param_feature_preprocessor:nystroem_sampler:coef0': nan,
#   'param_feature_preprocessor:nystroem_sampler:degree': nan,
#   'param_feature_preprocessor:nystroem_sampler:gamma': nan,
#   'param_feature_preprocessor:select_rates_classification:mode': nan}]

# %%
'../datasets/vectorized/aft_vectorized_01-29-21.json'.rsplit('.',1)
# Out:
# ['../datasets/vectorized/aft_vectorized_01-29-21', 'json']
