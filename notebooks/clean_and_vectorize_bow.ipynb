# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import sys

# %%
FILEPATH = '/Users/klogg/research_data/aft/raw/dump_03-24-20.csv'

dtypes = {
    'aft_id': object,
    'aft_comment':str,
    'aft_helpful':int,
    'aft_unhelpful':int
}

df = pd.read_csv(
    FILEPATH,
    escapechar='\\',
    encoding='latin-1',
    dtype=dtypes
)

# %%
vectorizer = TfidfVectorizer(
    strip_accents='unicode',
    lowercase=True,
    analyzer='word',
    max_df=.9,
    max_features=100000
)
tokenizer = vectorizer.build_tokenizer()

cols_to_extract = [
    'aft_id',
    'aft_page',
    'aft_page_revision',
    'aft_user',
    'aft_user_text',
    'aft_comment',
    'aft_noaction',
    'aft_inappropriate',
    'aft_helpful',
    'aft_unhelpful'
]

def process(observations, save_tokens=False, debug=False):
    if debug:
        observations = observations.sample(debug)
    observations = observations[cols_to_extract]
    observations['aft_comment'] = observations['aft_comment'].astype(str)
    observations['aft_net_sign_helpful'] = np.sign(observations['aft_helpful']-observations['aft_unhelpful']).astype(int)
    if save_tokens:
        observations['tokenized_text'] = observations['aft_comment'].apply(tokenizer)
    observations['feature_vector'] = vectorizer.fit_transform(observations['aft_comment'].values)
    return observations

observations = process(df,save_tokens=True,debug=10)
# Out:
#                                   aft_id  aft_page  aft_page_revision  \
# 840362  87475000000000000000000000000000    535865          481753920
# 778775  81576300000000000000000000000000    437943          529789529
# 644165  68700300000000000000000000000000    264917          524959139
# 41867   050b038a3c861027e9fe90b11c278d5a    244932          584632318
# 212377  26415400000000000000000000000000   7066937          504006206
# 226314  27795200000000000000000000000000    977935          507229271
# 181376  23352300000000000000000000000000   3524766          505623973
# 396218  44514600000000000000000000000000    511961          511986951
# 780925  81781500000000000000000000000000  16083989          531446887
# 742115  78069100000000000000000000000000  25855957          529612432
#
#         aft_user    aft_user_text  \
# 840362         0  194.171.252.101
# 778775         0    74.72.147.228
# 644165         0    206.78.191.85
# 41867          0   203.45.240.205
# 212377         0   117.213.135.57
# 226314         0     1.23.160.227
# 181376         0    174.29.175.48
# 396218         0    66.108.127.79
# 780925         0   111.68.105.221
# 742115         0    187.200.75.39
#
#                                               aft_comment  aft_noaction  \
# 840362                                                nan             0
# 778775          Treatments and possible future treatments             0
# 644165  hansel and gretel\ndoesn't want to get on\nlai...             0
# 41867                                                 nan             0
# 212377  Wonderful. Thank you it is useful for my proje...             0
# 226314                                                nan             0
# 181376  I just bought a new computer.  How do I get yo...             1
# 396218                                                nan             0
# 780925   give imvic result table for clostridium' strains             0
# 742115  This article could use a diagram for a deeper ...             1
#
#         aft_inappropriate  aft_helpful  aft_unhelpful  aft_net_sign_helpful  \
# 840362                  0            0              0                     0
# 778775                  0            0              0                     0
# 644165                  0            0              1                    -1
# 41867                   0            0              0                     0
# 212377                  0            1              0                     1
# 226314                  0            0              0                     0
# 181376                  0            0              1                    -1
# 396218                  0            0              0                     0
# 780925                  0            0              0                     0
# 742115                  0            0              0                     0
#
#                                            tokenized_text  \
# 840362                                              [nan]
# 778775    [Treatments, and, possible, future, treatments]
# 644165  [hansel, and, gretel, doesn, want, to, get, on...
# 41867                                               [nan]
# 212377  [Wonderful, Thank, you, it, is, useful, for, m...
# 226314                                              [nan]
# 181376  [just, bought, new, computer, How, do, get, yo...
# 396218                                              [nan]
# 780925  [give, imvic, result, table, for, clostridium,...
# 742115  [This, article, could, use, diagram, for, deep...
#
#                                            feature_vector
# 840362    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 778775    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 644165    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 41867     (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 212377    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 226314    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 181376    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 396218    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 780925    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...
# 742115    (0, 31)\t1.0\n  (1, 45)\t0.7812778040619008\...

# %%
x = vectorizer.fit_transform(observations['aft_comment'].values)[1]
y = vectorizer.fit_transform(observations['aft_comment'].values)

# %%
x
# Out:
# <1x54 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
type(tokenizer('This is text'))
# Out:
# list

# %%
'this is a test'.split(' ')
# Out:
# ['this', 'is', 'a', 'test']
